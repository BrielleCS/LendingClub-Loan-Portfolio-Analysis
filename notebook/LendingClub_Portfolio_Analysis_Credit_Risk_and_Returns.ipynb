# %% [markdown]
# # LendingClub Loan Portfolio Analysis: Credit Risk, Returns, and Portfolio Concentration
#
# ## Overview
# This analysis examines over 2.2M loans from the LendingClub accepted loans dataset issued between 2007–2018 to evaluate credit risk, loan performance, and portfolio concentration. To measure realized portfolio outcomes, the dataset was filtered to approximately 1.3M loans with finalized statuses — specifically Fully Paid and Charged Off loans — excluding loans still in repayment or other non-finalized statuses.
#
# A credit risk analysis is performed using Probability of Default (PD), Exposure at Default (EAD), and Loss Given Default (LGD) to evaluate observed default frequency, exposure at the time of default, and realized loss severity across credit grades. This analysis complements portfolio performance metrics by providing additional insight into credit risk differences across grades.
#
# Using SQL for aggregation, Python for preprocessing and modeling, and Tableau for dashboard development, the analysis focuses on key business questions related to borrower risk, portfolio returns, and concentration exposure.
#
# The analysis identifies high-risk borrower segments, evaluates risk-adjusted returns across credit grades, and examines how loan exposure is distributed across borrower categories and geographic regions.
#
# The workflow demonstrates end-to-end analytical and visualization skills across the modern data analytics stack.
#
# ---
#
# ## Executive Summary
# The following metrics reflect the filtered portfolio of finalized loans with `Fully Paid` or `Charged Off` statuses.
#
# ### Portfolio Performance & Risk Metrics
#
# - **Total Funded Volume**: \$19.4B
# - **Charged-Off Exposure (Origination Principal)**: \$4.2B
# - **Portfolio Default Rate (Charge-Off Rate)**: 21.55%
# - **Peak Cohort Default Rate**: 26.61% (July 2016 origination cohort)
# - **Risk Concentration (Pareto Analysis)**: 18 of 35 subgrades accounted for 80% of realized defaults
# - **Highest Risk Borrower Segment**: Renters with Grade G loans - 54.87% default rate
# - **Inequality Index**: 0.336 Gini Coefficient
# - **Realized Net Return**: \$543.4M
# - **Average Portfolio Interest Rate**: 13.65%
# - **Net Return Efficiency**: 2.80%
# - **Top Loan Purpose Exposure**: Debt Consolidation - 61.27% share, \$11.9B exposure
# - **Top State Concentration**: California - $2.9B exposure, 19.6% default rate
#
# ### Historical Credit Risk Metrics
#
# - **Total EAD**: \$3.0B in remaining principal exposure across charged-off loans at the time of default
# - **PD Range Across Grades**: 6.04% (Grade A) → 49.93% (Grade G), showing increasing default frequency across grades
# - **EAD Range Across Grades**: \\$80.2M (Grade G) → $883.3M (Grade C), showing differences in total remaining defaulted exposure across grades
# - **LGD Range Across Grades**: 88.81% (Grade F) → 89.67% (Grade A), showing relatively consistent realized loss severity across grades after recoveries
# - **Highest Risk Grade**: Grade G borrowers exhibited the highest observed default rate at 49.93%
#
# ### Key Insights
#
# **Underwriting Risk Trends** \
# Default rates peaked at 26.6% in July 2016 origination cohort, indicating a period of elevated credit risk and weaker underwriting performance.
#
# **Risk Distribution Across Borrower Segments** \
# Defaults were broadly distributed across the portfolio, with 18 of 35 subgrades contributing to 80% of total defaults. Renters with Grade G loans exhibited the highest observed default rate at 54.9%.
#
# **Risk vs. Return Trade-Off** \
# A clear risk-return trade-off emerged across credit grades. Performance was strongest in higher grades, where both returns were positive and default risk remained relatively low. Grades A and B delivered the highest net returns (~5%) with single-digit to low-teens default rates. Grade C marked the inflection point, where default rates exceeded the portfolio benchmark (21.55%) while returns began to decline. Grade D continued this deterioration, with near break-even returns and materially elevated default risk. From Grade E onward, returns turned negative and default rates increased sharply (above 35%).
#
# **Portfolio Concentration & Geographic Exposure** \
# The portfolio exhibited moderate concentration risk (Gini Coefficient = 0.336), with significant exposure to debt consolidation loans (61.27% of volume, \\$11.9B) and borrowers in California ($2.9B exposure).
#
# **Historical Credit Risk Patterns**
# Credit risk increased significantly across LendingClub grades, with PD rising from 6.04% in Grade A to 49.93% in Grade G. Lower-grade borrowers experienced substantially higher observed default frequency, demonstrating clear separation in credit performance across the grading structure.
#
# **Exposure and Loss Severity Trends**
# EAD varied across grades, reflecting differences in the amount of remaining principal exposure among charged-off loans. LGD remained relatively consistent across grades at approximately 89%, indicating that loss severity was primarily driven by default occurrence rather than significant differences in recovery performance.
#
# **Credit Risk Concentration** \
# The highest-risk portion of the portfolio was concentrated among lower credit grades, particularly Grade G borrowers, which exhibited the highest observed default rate. This highlights the importance of monitoring borrower quality and maintaining appropriate risk differentiation during loan origination.
#
# **Relationship Between Credit Risk and Portfolio Performance**
# Higher-risk grades exhibited substantially higher observed default rates, contributing to weaker realized portfolio performance across lower credit grades. The increase in default frequency across grades highlights the importance of evaluating credit quality alongside portfolio outcomes when assessing lending performance.
#
# ### Business Recommendations
#
# - Implement automated monitoring of underwriting performance and historical credit risk trends to identify deteriorating loan quality and elevated default risk earlier.
# - Strengthen underwriting controls for lower credit grades where observed default rates increase substantially, particularly among Grade G borrowers.
# - Apply risk-based pricing strategies across credit grades to ensure loan yields appropriately compensate for observed default risk and loss severity.
# - Use historical PD trends by grade to monitor changes in borrower credit performance and identify segments requiring additional risk review.
# - Monitor EAD concentration to understand where remaining default exposure is concentrated and prioritize risk management efforts toward higher-exposure segments.
# - Continue evaluating recovery performance and LGD trends to identify opportunities to improve collection strategies and reduce realized loss severity.
# - Evaluate lending strategies using historical risk-adjusted performance across grades while maintaining appropriate pricing and underwriting standards for higher-risk grades.
# - Diversify portfolio exposure across loan purposes, geographic regions, and borrower characteristics to reduce concentration risk and improve portfolio resilience.
# ---
#
# ## Business Questions & Key Metrics
#
# #### 1. Portfolio Health & Default Trends
#
# How does loan performance vary across loan origination cohorts from 2007–2018, and what patterns emerge in portfolio credit risk over time?
#
# ##### Key Metrics:
#
#   - **Funded Volume Distribution** - aggregated funded amount of finalized loans across all grades
#   - **Default Rate by Grade** - percentage of charged off loans within each grade
#   - **Cohort Default Rate Over Time** - monthly trend of default rates based on loan origination month (issue date) from 2007–2018
#
# #### 2. Default Contribution & Risk Distribution
#
# Which grades contribute most to loan defaults, and how is risk distributed across subgrades and borrower segments?
#
# ##### Key Metrics:
#
#   - **Default Contribution by Grade** - share of total defaults by grade
#   - **Default Contribution by Subgrade** - granular breakdown of total defaults across 35 subgrades
#   - **Risk Matrix: Homeownership vs. Grade** - default rates by borrower occupancy status and grade
#
# #### 3. Risk vs. Return
#
# How does net return performance vary across grades relative to default risk?
#
# ##### Key Metrics:
#
#   - **Average Interest Rate** - average yield by grade
#   - **Net Return** - profit or loss after loan completion across all grades
#   - **Net Return Efficiency** - percentage of principal recovered as profit segmented by grade
#   - **Risk vs. Return** - comparison of default rates versus net returns across all grades
#
# #### 4. Portfolio Concentration & Diversification Risk
#
# Is the portfolio heavily concentrated across specific borrower segments or geographic regions?
#
# ##### Key Metrics:
#
#   - **Portfolio Concentration Index (Gini Coefficient)** - measures inequality of exposure distribution
#   - **Loan Purpose Concentration** - exposure by borrower intent
#   - **Geographic Risk Exposure (State-Level Default Rates)** - regional variation in default risk
#
# #### 5. Historical Credit Risk Analysis
#
# How do observed credit risk characteristics vary across borrower grades, and what factors contribute to differences in default probability, exposure at default, and loss severity?
#
# ##### Key Metrics:
#
# - **Probability of Default (PD)** - historical charge-off rate used to measure observed default frequency across borrower grades
# - **Exposure at Default (EAD)** - realized loan exposure at the time of default based on outstanding principal balance
# - **Loss Given Default (LGD)** - realized loss severity after accounting for principal recovery and recoveries received
# - **Credit Risk Metrics by Grade** - comparison of observed PD, EAD, and LGD across borrower grades
# ---
#
# ## Tools Used
# - **Python (Pandas, NumPy, Matplotlib, SQLAlchemy)** - data cleaning, transformation, preprocessing SQL-extracted datasets, portfolio analytics, and implementation of historical credit risk metrics, including PD, EAD, and LGD, as well as visualizing Lorenz curve and Gini coefficient
# - **PostgreSQL** - data querying, aggregations, and transformations using CTEs and window functions
# - **Tableau Public** - interactive dashboards and KPI visualization of aggregated datasets
# - **Jupyter Notebook** - workflow orchestration and documentation of analysis
# - **Git / GitHub** - version control and portfolio hosting
#
# ---
#
# ## Technical Setup
# All SQL queries are executed within Jupyter Notebook using a PostgreSQL connection via Python (Pandas + SQLAlchemy). Cleaned and aggregated datasets are exported from SQL and used in Tableau for dashboard development and visualization.
#
# The Lorenz curve and Gini coefficient are computed in Python due to the large dataset size (~1.3M borrowers) and the need for borrower-level cumulative calculations, ensuring computational efficiency and scalability. The resulting visualization is embedded in a Tableau dashboard. Tableau is used for all other aggregated visualizations.
#
# Historical credit risk analysis is implemented in Python to calculate PD, EAD, and LGD across grades. These metrics are used to evaluate observed default behavior, exposure levels, and loss severity within the finalized loan portfolio.
#
# All required libraries are imported and defined at the beginning of the analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter, StrMethodFormatter
# from sqlalchemy import create_engine
# engine = create_engine('postgresql://username:password@localhost:5432/postgres')

# %% [markdown]
# ---
# ## Analysis Workflow (Dashboard Architecture & Credit Risk Analysis)
# This analysis begins with data preparation, followed by four dashboards representing distinct layers of credit portfolio evaluation — from performance and risk to profitability and portfolio concentration. This analysis concludes with a Python-based historical credit risk analysis that estimates PD, EAD, LGD across grades, providing additional insight into historical credit risk characteristics and loss severity.
#
# ### Data Preparation
# - Data Exploration, Filtering, and Cleaning
#
# ---
# ### Dashboard 1: Executive Portfolio Health Overview (Realized Portfolio)
# - Funded Volume Distribution
# - Default Rate
# - Cohort Default Rate by Origination Month (2007–2018)
#
# ---
# ### Dashboard 2: Default Contribution & Risk Distribution
# - Default Contribution by Grade (Pareto)
# - Default Contribution by Subgrade (Pareto)
# - Risk Matrix: Homeownership vs. Grade
#
# ---
# ### Dashboard 3: Credit Risk & Return Analysis
# - Net Return
# - Net Return Efficiency
# - Risk vs. Return
# - Average Interest Rate
#
# ---
# ### Dashboard 4: Strategic Exposure & Diversification
# - Geographic Risk Exposure
# - Portfolio Concentration & Inequality (Lorenz Curve & Gini Coefficient)
# - Portfolio Concentration by Loan Purpose
#
# ---
# ### Historical Credit Risk Analysis
# - Probability of Default (PD) Estimation
# - Exposure at Default (EAD) Estimation
# - Loss Given Default (LGD) Estimation
# - Credit Risk Summary Table by Grade
# - Credit Risk Metrics by Grade (plot)
#
# ---

# %% [markdown]
# ## Data Preparation
#
# This section inspects the LendingClub dataset to understand its structure, size, and key variables before proceeding with this analysis.
#
# Due to the large dataset size (2.2M+ rows), preprocessing was performed using a memory-efficient chunking approach in Python. The filtered dataset was then cleaned and prepared for all subsequent analyses.
#
# ### Key Steps:
# - Loaded the LendingClub accepted loans dataset (151 columns) covering 2007–2018
# - Applied filtering and column selection during chunked processing prior to exporting the reduced dataset
#     - Selected 22 relevant columns for analyzing loan performance, realized credit risk, returns, and portfolio concentration
#     - Processed the dataset in 100k-row chunks to efficiently manage memory usage during preprocessing
#     - Filtered the dataset to include only `Fully Paid` and `Charged Off` loans to ensure accurate measurement of default rates and realized returns, resulting in approximately 1.3M records
# - Handled missing values by imputing the categorical variable (`emp_length`) with `Unknown`, filling missing numeric values (`recoveries` and `collection_recovery_fee`) with `0`, and retaining missing dates (`last_pymnt_d`) as `NaT`, where appropriate for time-based analysis
# - Converted date fields to datetime format and verified consistency across key numeric and categorical variables
# - Performed validation checks on row counts and loan status distributions to ensure data consistency

# %%
# -------------------------------
# Memory-Efficient CSV Filter
# -------------------------------

# Input and output paths
input_file = 'accepted_2007_to_2018Q4.csv'   # original large CSV
output_file = 'accepted_loans_filtered.csv'     # new filtered CSV

# Columns to keep
columns_to_keep = [
    'id', 'loan_amnt', 'term', 'int_rate', 'installment',
    'grade', 'sub_grade', 'emp_length', 'home_ownership', 
    'annual_inc', 'issue_d', 'loan_status', 'purpose', 
    'addr_state', 'fico_range_low', 'fico_range_high', 
    'total_pymnt', 'total_rec_prncp', 'total_rec_int',  
    'last_pymnt_d', 'recoveries', 'collection_recovery_fee'
]

# Chunk size (100k rows at a time)
chunksize = 100_000

# Process chunks and write to new CSV
first_chunk = True  # to write header only once

for chunk in pd.read_csv(input_file, chunksize=chunksize, usecols=columns_to_keep):
    
    # filter for only 'Fully Paid' and 'Charged Off' loans
    chunk = chunk[chunk['loan_status'].isin(['Fully Paid', 'Charged Off'])]    
    
    # Append to new CSV
    chunk.to_csv(output_file, mode='w' if first_chunk else 'a', index=False, header=first_chunk)

    # after first chunk, header is no longer written
    first_chunk = False  

print(f"Filtered CSV saved as '{output_file}' successfully!")

# %%
# Load filtered dataset
df = pd.read_csv("../data/accepted_loans_filtered.csv", low_memory=False)

# Handle missing categorical values
df['emp_length'] = df['emp_length'].fillna('Unknown')
df['recoveries'] = df['recoveries'].fillna(0)
df['collection_recovery_fee'] = df['recoveries'].fillna(0) 

# Convert date columns to datetime format; invalid values are coerced to NaT
df['issue_d'] = pd.to_datetime(df['issue_d'], errors='coerce')
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], errors='coerce')

# Export cleaned dataset
df.to_csv("accepted_loans_clean.csv", index=False, date_format='%Y-%m-%d')

#Create a small 1,000-row sample for GitHub
df.sample(n=1000, random_state=1).to_csv("../data/accepted_loans_sample.csv", index=False)

# Load cleaned dataset into PostgreSQL
df.to_sql('accepted_loans', engine, if_exists='replace', index=False)

# Validation checks
print("Loan status distribution:")
print(df["loan_status"].value_counts())

print("\nDataset size:")
print(len(df))

print("\nMissing values summary:")
print(df.isnull().sum().sort_values(ascending=False).head(10).to_string())
# Out:
# Loan status distribution:
# loan_status
# Fully Paid     1076751
# Charged Off     268559
# Name: count, dtype: int64
#
# Dataset size:
# 1345310
#
# Missing values summary:
# last_pymnt_d       2313
# id                    0
# loan_amnt             0
# recoveries            0
# total_rec_int         0
# total_rec_prncp       0
# total_pymnt           0
# fico_range_high       0
# fico_range_low        0
# addr_state            0

# %% [markdown]
# ---
# ## Dashboard 1: Executive Portfolio Health Overview

# %% [markdown]
# ### Funded Volume & Default Rate by Grade Dataset

# %%
query = """
WITH loan_data AS (
     SELECT grade, 
            SUM(loan_amnt) AS total_loan_exposure, 
            COUNT(*) FILTER (WHERE loan_status = 'Charged Off') AS charge_off_count,
            COUNT(*) AS total_count
     FROM accepted_loans
     GROUP BY grade
     )
SELECT grade,   
       total_loan_exposure,
       ROUND((charge_off_count * 100.0 / NULLIF(total_count,0)), 2) AS default_rate_pct
FROM loan_data
ORDER BY grade
"""

# SQL execution (kept for transparency; not run in final notebook)
# df_exposure_and_default = pd.read_sql(query, engine)
# df_exposure_and_default.to_csv("../data/exposure_and_default.csv", index=False)

# Load pre-generated dataset for reproducibility
df_exposure_and_default = pd.read_csv("../data/exposure_and_default.csv")

# %% [markdown]
# ### Cohort Default Rate by Origination Month (2007–2018)
# Monthly cohort-level default rate calculated using loan origination month (`issue_d`), measuring the proportion of loans that resulted in charge-off within each origination cohort.

# %%
query = """
WITH loan_counts AS (
     SELECT DATE_TRUNC('year', issue_d) AS year,
            DATE_TRUNC('month', issue_d) AS month,
            COUNT(*) FILTER (WHERE loan_status = 'Charged Off') AS charge_off_count,
            COUNT(*) AS total_count
            FROM accepted_loans
            GROUP BY year, month
     )
SELECT year, 
       month, 
       ROUND((charge_off_count * 100.0 / NULLIF(total_count, 0)), 2) AS default_rate_pct
FROM loan_counts
ORDER BY year, month
"""

#df_default_rate_time = pd.read_sql(query, engine)
#df_default_rate_time.to_csv("../data/default_rate_pct_time.csv", index=False)
df_default_rate_time = pd.read_csv("../data/default_rate_pct_time.csv")

# %% [markdown]
# ---
#
# ![Executive Portfolio Health Overview Dashboard](../images/Executive_Portfolio_Health_Overview.png)
#
# ---

# %% [markdown]
# ## Dashboard 2: Default Contribution & Risk Distribution

# %% [markdown]
# ### Default Contribution Dataset (Pareto Construction)
# Default contribution of realized losses across grades and subgrades used for Pareto analysis to assess whether a small number of grades and subgrades account for most of the total losses.

# %%
query = """
WITH defaults AS (
     SELECT 
        grade, sub_grade,
        SUM(loan_amnt)::numeric AS default_amount
     FROM accepted_loans
     WHERE loan_status = 'Charged Off'
     GROUP BY grade, sub_grade
     ),
   cum_sum AS (
    SELECT
        grade, sub_grade,
        default_amount,
        default_amount * 1.0 / SUM(default_amount) OVER () * 100 AS default_contribution_pct,
        SUM(default_amount) OVER (ORDER BY default_amount DESC) / SUM(default_amount) OVER () * 100 AS cumulative_pct
    FROM defaults
    )
SELECT
    grade, sub_grade,
    ROUND(default_amount, 2) AS default_amount,
    ROUND(default_contribution_pct, 2) AS default_contribution_pct,
    ROUND(cumulative_pct, 2) AS cumulative_pct
FROM cum_sum
ORDER BY default_amount DESC
"""

# SQL execution (kept for transparency; not executed in final notebook)
# df_default_contribution = pd.read_sql(query, engine)
# df_default_contribution.to_csv("../data/default_contribution_pareto.csv", index=False)

df_default_contribution = pd.read_csv("../data/default_contribution_pareto.csv")

# %% [markdown]
# ### Segment Exposure Dataset
# Base dataset used for multiple analyses including:
# - Risk Matrix: Homeownership vs. Grade
# - Geographic Risk Exposure by State (Dashboard 4)
# - Portfolio Concentration by Loan Purpose (Dashboard 4)

# %%
query = """
SELECT grade, sub_grade, purpose, addr_state, home_ownership,
       SUM(loan_amnt) AS total_exposure,
       COUNT(id) AS loan_count,
       SUM(CASE WHEN loan_status = 'Charged Off' THEN 1 ELSE 0 END) AS default_count,
       AVG(int_rate) AS avg_int_rate
FROM accepted_loans
GROUP BY 1, 2, 3, 4, 5
"""

# df_segment_exposure = pd.read_sql(query, engine)
# df_segment_exposure.to_csv("../data/segment_exposure.csv", index=False)
df_segment_exposure = pd.read_csv("../data/segment_exposure.csv")

# %% [markdown]
# ---
# ![Default Contribution & Risk Distribution Dashboard](../images/Default_Contribution_&_Risk_Distribution.png)
#
# ---

# %% [markdown]
# ## Dashboard 3: Credit Risk & Return Analysis

# %% [markdown]
# ### Credit Risk & Return Dataset
# Grade-level aggregated dataset for return, risk, and interest rate metrics

# %%
query = """ 
WITH loan_data AS (
     SELECT grade, 
            SUM(total_pymnt - loan_amnt) AS total_net_return,
            COUNT(*) FILTER (WHERE loan_status = 'Charged Off') AS charge_off_count,
            COUNT(*) AS total_count,
            (SUM(total_pymnt) - SUM(loan_amnt)) / SUM(loan_amnt) * 100 AS net_return_pct,
            AVG(int_rate) AS avg_int_rate
     FROM accepted_loans
     GROUP BY grade
     )
SELECT grade,
       total_net_return,
       net_return_pct,
       ROUND((charge_off_count * 100.0 / NULLIF(total_count, 0)), 2) AS default_rate_pct,
       avg_int_rate
FROM loan_data
ORDER BY grade
"""

# SQL execution (kept for transparency; not executed in final notebook)
# df_return_risk_int = pd.read_sql(query, engine)
# df_return_risk_int.to_csv("../data/return_risk_int.csv", index=False)

df_return_risk_int = pd.read_csv("../data/return_risk_int.csv")

# Weighted average interest rate across realized loans
df = pd.read_csv('../data/accepted_loans_clean.csv')
weighted_avg = np.average(df['int_rate'], weights = df['loan_amnt'])
print(f"Realized Average Interest Rate: {weighted_avg:.2f}%")
# Out:
# Realized Average Interest Rate: 13.65%

# %% [markdown]
# ---
# ![Profitability & Yield Metrics Dashboard](../images/Profitability_&_Yield_Metrics.png)
#
# ---

# %% [markdown]
# ## Dashboard 4: Strategic Exposure & Diversification
#
# ### Segment Exposure Dataset (reused from Dashboard 2)
# Used for:
# - Geographic Risk Exposure by State
# - Portfolio Concentration by Loan Purpose

# %% [markdown]
# ### Portfolio Concentration & Inequality (Lorenz Curve & Gini Coefficient)
#
# Loan exposure distribution across borrowers is visualized using a Lorenz curve, highlighting the degree of concentration within the portfolio for Fully Paid and Charged Off loans. The Gini coefficient is computed to quantify inequality in loan exposure distribution, providing a single metric of concentration.
#
#   The Gini Coefficient ranges from:\
#     0 → Perfect equality (loan exposure evenly distributed across all borrowers)\
#     1 → Perfect concentration (all loan exposure held by a single borrower)

# %%
# Load cleaned dataset
df_lorenz = pd.read_csv("../data/accepted_loans_clean.csv")

# Prepare Lorenz curve data
loan_amnt_sorted = np.sort(df_lorenz['loan_amnt'])
cumulative_amnt = np.cumsum(loan_amnt_sorted)
cumulative_amnt = cumulative_amnt / cumulative_amnt[-1]
cumulative_id = np.arange(1, len(loan_amnt_sorted)+1) / len(loan_amnt_sorted)

# Plot Lorenze Curve
plt.figure(figsize=(12,6))
plt.plot(cumulative_id, cumulative_amnt, label='Lorenz Curve', color='blue')
plt.plot([0,1], [0,1], linestyle='--', color='gray', label='Perfect Equality')

# Shading Inequality Area
plt.fill_between(cumulative_id, cumulative_amnt, cumulative_id, color='orange', alpha=0.3, label='Inequality Area')

plt.title('Lorenz Curve - Loan Portfolio Concentration', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Cumulative Share of Borrowers', fontsize=12, fontweight='bold', labelpad=15)
plt.ylabel('Cumulative Share of Loan Amount', fontsize=12, fontweight='bold', labelpad=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

# Compute and plot Gini coefficient
gini = 1 - 2 * np.trapz(cumulative_amnt, cumulative_id)
plt.text(0.6, 0.2, f'Gini Coefficient: {gini:.3f}', fontsize=11, bbox=dict(facecolor='white', alpha=0.6))

#plt.savefig("../images/lorenz_curve.png", dpi=300, bbox_inches="tight")
#plt.show()

# Construct and save Lorenz curve dataset for later Tableau visualization
lorenz_df = pd.DataFrame({"cumulative_borrowers": cumulative_id, "cumulative_loan_amount": cumulative_amnt})
lorenz_df.to_csv("../data/lorenz_curve.csv", index=False)

# Save Gini coefficient
gini_df = pd.DataFrame({"gini_coefficient": [gini]})
gini_df.to_csv("../data/gini_coefficient.csv", index=False)

# %% [markdown]
# ---
# ![Strategic Exposure & Diversification Dashboard](../images/Strategic_Exposure_&_Diversification.png)
#
# ---

# %% [markdown]
# ## Historical Credit Risk Analysis
# Loan-level data is processed to construct grade-based credit risk measures. The workflow involves:
#
# - Identifying defaulted loans using loan status flags
# - Aggregating borrower segments by grade for risk segmentation
# - Computing exposure and loss measures at the loan level
# - Calculating historical PD, EAD, and LGD
# - Summarizing credit risk measures by grade for portfolio comparison
#
# The final outputs include a credit risk summary table and a grade-level bar chart comparing historical PD, EAD, and LGD across credit grades.

# %%
# ============================================================
# 1. PROBABILITY OF DEFAULT (PD)
# ============================================================
# Create default indicator:
# Charged Off = 1
# Fully Paid = 0

df['is_default'] = (df['loan_status'] == 'Charged Off').astype(int)

# Calculate historical PD by grade
pd_table = (df.groupby('grade').agg(total_loans=('loan_status', 'count'), 
                                    default_loans=('is_default', 'sum'),
                                    PD=('is_default', 'mean')).reset_index())

# ============================================================
# 2. CREATE DEFAULT-ONLY DATASET
# ============================================================
# EAD and LGD are calculated only on loans that defaulted

df_defaults = df[df['loan_status'] == 'Charged Off'].copy()

# ============================================================
# 3. EXPOSURE AT DEFAULT (EAD)
# ============================================================
# Estimated remaining exposure at the time of default:
# Original Loan Amount - Principal Repaid

df_defaults['EAD'] = (df_defaults['loan_amnt'] - df_defaults['total_rec_prncp'])

# Prevent negative values
df_defaults['EAD'] = df_defaults['EAD'].clip(lower=0)

# ============================================================
# 4. LOSS GIVEN DEFAULT (LGD)
# ============================================================
# Realized Loss:
# Original Loan Amount - Principal Recovered - Recoveries

df_defaults['loss'] = (df_defaults['loan_amnt'] - df_defaults['total_rec_prncp'] - df_defaults['recoveries'])

# Prevent negative losses
df_defaults['loss'] = df_defaults['loss'].clip(lower=0)

# LGD = Loss / EAD

df_defaults['LGD'] = (df_defaults['loss'] / df_defaults['EAD'])

# Handle divide-by-zero cases
df_defaults['LGD'] = (df_defaults['LGD'].replace([np.inf, -np.inf], np.nan).fillna(0))

# ============================================================
# 5. SUMMARIZE CREDIT RISK METRICS BY GRADE
# ============================================================

credit_risk_table = (df_defaults.groupby('grade')
                    .agg(EAD=('EAD', 'sum'), 
                         LGD=('LGD', 'mean'))
                    .reset_index())

# Add loan counts and PD back to the summary table
credit_risk_table = credit_risk_table.merge(pd_table, on='grade', how='left')

# ============================================================
# 8. FINAL OUTPUT TABLE
# ============================================================

credit_risk_table = credit_risk_table[['grade', 'total_loans', 'default_loans', 'PD', 'EAD', 'LGD']]

# Sort by highest PD first
credit_risk_table = credit_risk_table.sort_values(by='PD', ascending=False)

# Save historical credit risk Table
# credit_risk_table.to_csv("../data/credit_risk_table.csv", index=False)

# %%
# ============================================================
# FORMAT HISTORICAL CREDIT RISK TABLE AND DISPLAY
# ============================================================
credit_risk_display = credit_risk_table.copy()

# Convert PD and LGD to percentages
credit_risk_display['PD'] = (credit_risk_display['PD'] * 100).round(2).astype(str) + '%'
credit_risk_display['LGD'] = (credit_risk_display['LGD'] * 100).round(2).astype(str) + '%'

# Round dollar-based values
credit_risk_display['EAD'] = credit_risk_display['EAD'].round(0).astype(int)
credit_risk_display['EAD'] = credit_risk_display['EAD'].apply(lambda x: f"${x:,.0f}")

# Display formatted table
credit_risk_display.style.set_table_styles([{'selector': 'th', 'props': [('padding', '10px 15px'), ('text-align', 'center')]},
                                     {'selector': 'td', 'props': [('padding', '10px 15px'), ('text-align', 'center')]}])

fig, ax = plt.subplots(figsize=(12, 4))
ax.axis('off')

ax.set_title("Historical Credit Risk Summary by Grade", fontsize=16, fontweight='bold', pad=5)

table = ax.table(cellText=credit_risk_display.values, 
                 colLabels=credit_risk_display.columns, 
                 cellLoc='center', 
                 colLoc='center', 
                 loc='center')

table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 2.1)

# Style header row
for (row, col), cell in table.get_celld().items():
    if row == 0:
        cell.set_text_props(weight='bold')
        cell.set_facecolor('#D9EAD3')

plt.tight_layout()

# plt.savefig("../images/historical_credit_risk_table.png", dpi=300, bbox_inches='tight')

plt.show()

# %%
# ============================================================
# CREDIT RISK MULTI-METRIC VISUALIZATION
# ============================================================

ax = credit_risk_table.set_index('grade')[['PD','LGD','EAD']].plot(kind='bar', figsize=(12,6), secondary_y='EAD', mark_right=False)

# Primary y-axis (PD and LGD)
ax.set_ylim(0, 1) 
ax.yaxis.set_major_formatter(PercentFormatter(1.0))
ax.set_ylabel('PD / LGD (%)', fontsize=12, fontweight='bold', fontname='Arial', labelpad=10)

# Secondary y-axis (EAD)
ax.right_ax.set_ylim(0, 900000000)
ax.right_ax.yaxis.set_major_formatter(StrMethodFormatter('${x:,.0f}'))
ax.right_ax.set_ylabel('EAD ($)', fontsize=12, fontweight='bold', fontname='Arial', labelpad=10)

# x-axis (Grade)
ax.set_xlabel("Grade", fontsize=12, fontweight='bold', fontname='Arial', labelpad=10)
ax.tick_params(axis='x', labelrotation=0)

plt.title("Credit Risk Components by Grade", fontsize=18, fontweight='bold', fontname='Arial', pad=15)

# Formatting legend
handles1, labels1 = ax.get_legend_handles_labels()
handles2, labels2 = ax.right_ax.get_legend_handles_labels()
ax.legend(handles1 + handles2, labels1 + labels2, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)

plt.tight_layout()

#plt.savefig("../images/credit_risk_components.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Interpretation
#
# - **Grade G** exhibits the highest PD (49.93%) but the lowest total EAD ($80.2M), indicating that while these loans are the riskiest on an individual basis, they represent a relatively small share of the portfolio's remaining exposure.
#
# - **Grade C** has one of the lowest observed PD rates (22.44%) but the highest total EAD ($883.3M), suggesting that it represents a substantial portion of the lending portfolio. As a result, changes in default performance within this grade could have a meaningful impact on overall portfolio losses.
#
# - **Grade A** demonstrates both the lowest PD (6.04%) and second lowest EAD ($115M), reflecting strong credit quality and limited contribution to overall portfolio credit risk.
#
# - **Overall Observation**: The results show that default probability and exposure measure different dimensions of credit risk. While lower credit grades exhibit higher default frequencies, the greatest portfolio exposure is concentrated in mid-grade loans, highlighting the importance of evaluating both default likelihood and exposure when assessing portfolio risk.

# %% [markdown]
# ---
# ## Conclusion
#
# This analysis evaluated LendingClub loan performance across credit grades, borrower segments, and geographic regions using a filtered portfolio of finalized loans from 2007–2018. The results highlighted relationships between credit risk, portfolio performance, and profitability while identifying concentrated sources of default exposure across borrower segments.
#
# In addition to analyzing realized portfolio outcomes, a historical credit risk analysis was performed using Probability of Default (PD), Exposure at Default (EAD), and Loss Given Default (LGD) to evaluate observed default frequency, remaining exposure at the time of default, and realized loss severity across credit grades. The analysis demonstrated that differences in credit performance were primarily driven by variation in default rates across grades, while loss severity remained relatively consistent.
#
# This analysis combined SQL, Python, and Tableau to deliver an end-to-end analytics workflow spanning data preparation, portfolio risk analysis, credit risk assessment, and executive-level dashboard reporting.

# %% [markdown]
# ---
# ## Future Extension: Forward-Looking Credit Risk Modeling
#
# A future extension will build upon this analysis by developing a forward-looking Current Expected Credit Loss (CECL) framework using the full LendingClub dataset, incorporating non-finalized loans and additional predictive risk factors to estimate future expected credit losses. The future analysis will also explore machine learning techniques, including XGBoost, to estimate PD using multiple borrower characteristics, compare model-based risk predictions with traditional credit grade segmentation, incorporate FICO score segmentation for comparative risk analysis, and evaluate portfolio resilience through stress testing under alternative credit risk scenarios.
